# %%
import finesse.virgo

# %% [markdown]
# ## Optimize thermal lenses' focal length

# %%
virgo = finesse.virgo.Virgo()

print('Before tuning')
# step 1: adjust the cavity lengths
virgo.adjust_PRC_length()
virgo.adjust_SRC_length()

# step 2: pretune
virgo.print_thermal_values()
virgo.optimize_TL(verbose=True)

virgo.plot_DARM()
virgo.print_thermal_values()
# Out:
# Before tuning
# ┌───────────────────╥─────────────┐
# │ Thermal Parameter ║    Value    │
# ╞═══════════════════╬═════════════╡
# │      PR.Rcx       ║    -1430.00 │
# │      PR.Rcy       ║    -1430.00 │
# │      SR.Rcx       ║     1430.00 │
# │      SR.Rcy       ║     1430.00 │
# │     f_CPN_TL      ║  -338008.00 │
# │     f_CPW_TL      ║  -353134.00 │
# └───────────────────╨─────────────┘
#
# ΔCPN_TL.f =  338006.0
# ΔCPW_TL.f =  353132.0
# ΔCPN_TL.f =  5642.573107407719
# ΔCPW_TL.f =  5054.9186115069315
# ΔCPN_TL.f =  3649.6270173111116
# ΔCPW_TL.f =  4249.034302548971
# ΔCPN_TL.f =  2686.0537620553514
# ΔCPW_TL.f =  3258.023239994771
# ΔCPN_TL.f =  1986.0022238304373
# ΔCPW_TL.f =  2486.5934813835192
# ΔCPN_TL.f =  1473.2838844250655
# ΔCPW_TL.f =  1891.3698067099322
# ΔCPN_TL.f =  1095.3136703815544
# ΔCPW_TL.f =  1435.1197652051924
# ΔCPN_TL.f =  815.5014013856417
# ΔCPW_TL.f =  1087.022638258757
# ΔCPN_TL.f =  607.6655663828715
# ΔCPW_TL.f =  822.7284055489581
# ΔCPN_TL.f =  452.8764859138173
# ΔCPW_TL.f =  622.4917151467525
# ΔCPN_TL.f =  337.3137264196994
# ΔCPW_TL.f =  470.89974729774985
# ΔCPN_TL.f =  251.12174821674125
# ΔCPW_TL.f =  356.73386031371774
# ┌───────────────────╥─────────────┐
# │ Thermal Parameter ║    Value    │
# ╞═══════════════════╬═════════════╡
# │      PR.Rcx       ║    -1430.00 │
# │      PR.Rcy       ║    -1430.00 │
# │      SR.Rcx       ║     1430.00 │
# │      SR.Rcy       ║     1430.00 │
# │     f_CPN_TL      ║  -319010.67 │
# │     f_CPW_TL      ║  -374868.94 │
# └───────────────────╨─────────────┘
